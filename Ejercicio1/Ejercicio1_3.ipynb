# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt
from math import *
from tqdm import *

# %%
data = open('ejercicio1_3.txt','r')
aux = data.readlines()
n = len(aux)
sur = np.zeros(n)

for i in range(n):
    aux[i] = aux[i].split()
    sur[i] = aux[i][0]

data.close()

# %%
his = np.zeros(n)

for i in tqdm(range(n)):
    his[i]=np.fix(abs(sur[i])*10**(-np.floor(log10(abs(sur[i])))))
# Out:
# 100%|██████████| 265/265 [00:00<?, ?it/s]

# %%
bins=[0.5,1.5,2.5,3.5,4.5,5.5,6.5,7.5,8.5,9.5]
points=np.linspace(1,9,9)
bl = np.array([0.301,0.176,0.125,0.097,0.079,0.067,0.058,0.051,0.046])*np.size(sur)
plt.hist(his,bins)
plt.plot(points,bl,'.',label='Ley de Benford')
plt.xlim([0.5,9.5])
plt.xlabel('1ª cifra significativa')
plt.legend()
plt.savefig('ejercicio1_3')
plt.show()
